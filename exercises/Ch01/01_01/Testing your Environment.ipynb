# %% [markdown]
# # Testing your Environment
#
# Try running the following cells to make sure you have everything correctly installed.

# %%
#Since Codespaces is a stripped down version
#Libraries might not be installed so lets add them
#Run the following in your terminal
pip install numpy matplotlib opencv-python


#Graphic Libraries might not be installed with lightweight installs so lets add them too.
#apt or package manager for Debian/Ubuntu will help get and install libgl1 and libgl1-mesa-glx from the package repo online.
sudo apt update
sudo apt-get update
sudo apt-get install -y libgl1-mesa-glx
sudo apt-get install -y libgl1

# %%
# First let's check your Python version

import sys 
print("Python version",sys.version)

#Let's check if your kernel/interpreter/terminal is using the same path as your notebook.
#Run this on your terminal:
#which python
print(sys.executable)

# %%
# Now check your version of Numpy and create a matrix

import numpy as np
print("Numpy version",np.version.version)
m = np.array([[1,2],[3,4]])
print(m)

# %%
# Now let's try opening an image and displaying it with Matplotlib:

import matplotlib.pyplot as plt
# %config InlineBackend.figure_formats = 'retina'

img = plt.imread('komodo.jpg')
plt.axis("off")
plt.imshow(img)

# %%
# Lastly, let's open an image using OpenCV
import cv2

print("OpenCV version",cv2.__version__)
image = cv2.imread('komodo.jpg')

# OpenCV loads images in BGR format; convert to RGB for proper display
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display the image with matplotlib
plt.axis("off")
plt.imshow(image_rgb)
plt.show()

# %%
import cv2

print("OpenCV version",cv2.__version__)
image = cv2.imread('komodo.jpg')

# OpenCV loads images in BGR format; convert to RGB for proper display
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display the image with matplotlib
plt.axis("off")
plt.imshow(image_rgb)
plt.show()

# %% [markdown]
# # You're good to go!
